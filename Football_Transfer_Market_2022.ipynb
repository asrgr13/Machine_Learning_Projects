# %% [markdown]
# # Football Transfer Market Analysis

# %% [markdown]
# This project is intended to analyse the European football transfer market from the year 2022 and create a summary of the market activity.
#
# Data source: https://www.kaggle.com/code/brunopincet/football-summer-market-analysis/input

# %% [markdown]
# ## 1. Load Packages and Dataset

# %% [markdown]
# ### Packages are taken from the project dataset link reference

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Change the path and filename depending on where you save the data file and renaming the file

df = pd.read_csv('/content/drive/MyDrive/PROA Final Project/Summer22_FootballTransfers.csv')

# %%
## Data summary
df.info()
print(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33825 entries, 0 to 33824
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 33825 non-null  object
#  1   position             33824 non-null  object
#  2   age                  33674 non-null  float64
#  3   origin_club          33825 non-null  object
#  4   league_origin_club   32903 non-null  object
#  5   country_origin_club  32903 non-null  object
#  6   new_club             33825 non-null  object
#  7   league_new_club      28351 non-null  object
#  8   country_new_club     28351 non-null  object
#  9   player_valuje        33825 non-null  object
#  10  cost                 33825 non-null  object
#  11  date_of_transfer     33825 non-null  object
# dtypes: float64(1), object(11)
# memory usage: 3.1+ MB
# (33825, 12)

# %%
df.head()
# Out:
#             name          position   age        origin_club  \
# 0   Amine Gouiri    Centre-Forward  22.0           OGC Nice
# 1     Umar Sadiq    Centre-Forward  25.0         UD Almería
# 2   Carlos Soler  Central Midfield  25.0        Valencia CF
# 3  Manuel Akanji       Centre-Back  27.0  Borussia Dortmund
# 4      Wout Faes       Centre-Back  24.0        Stade Reims
#
#   league_origin_club country_origin_club             new_club league_new_club  \
# 0            Ligue 1              France     Stade Rennais FC         Ligue 1
# 1             LaLiga               Spain        Real Sociedad          LaLiga
# 2             LaLiga               Spain  Paris Saint-Germain         Ligue 1
# 3         Bundesliga             Germany      Manchester City  Premier League
# 4            Ligue 1              France       Leicester City  Premier League
#
#   country_new_club player_valuje     cost date_of_transfer
# 0           France       €42.00m  €28.00m       2022-09-01
# 1            Spain       €18.00m  €20.00m       2022-09-01
# 2           France       €50.00m  €18.00m       2022-09-01
# 3          England       €30.00m  €17.50m       2022-09-01
# 4          England       €10.00m  €17.00m       2022-09-01

# %% [markdown]
# ## 2. Data Cleansing

# %%
df['cost'].unique()
# Out:
# array(['€28.00m', '€20.00m', '€18.00m', '€17.50m', '€17.00m', '€15.00m',
#        '€12.00m', '€11.00m', '€10.40m', '€10.00m', '€9.00m', '€7.00m',
#        '€6.00m', '€5.50m', '€5.00m', 'Loan fee:€4.50m', '€4.50m',
#        '€4.40m', '€4.10m', '€4.00m', 'Loan fee:€3.00m', '€3.00m',
#        '€2.60m', 'Loan fee:€2.50m', 'Loan fee:€2.31m', '€2.30m',
#        'Loan fee:€2.00m', '€2.00m', '€1.90m', 'Loan fee:€1.50m', '€1.50m',
#        '€1.04m', '€1.00m', 'Loan fee:€1.00m', '€958Th.', '€900Th.',
#        '€700Th.', 'Loan fee:€600Th.', '€600Th.', '€580Th.', '€500Th.',
#        'Loan fee:€500Th.', '€390Th.', '€350Th.', '€300Th.',
#        'Loan fee:€300Th.', '€200Th.', '€156Th.', '€150Th.', '€114Th.',
#        'Loan fee:€100Th.', '€55Th.', '€35Th.', 'Loan fee:€20Th.',
#        'free transfer', 'loan transfer', '?', '-', '€80.40m',
#        'Loan fee:€4.00m', '€2.62m', '€2.50m', '€1.80m', '€1.20m',
#        '€490Th.', '€450Th.', 'Loan fee:€400Th.', '€250Th.', '€60Th.',
#        'Loan fee:€25Th.', '€5Th.', '€95.00m', '€50.00m', '€23.00m',
#        '€8.50m', '€8.00m', '€4.20m', '€2.20m', '€1.35m', '€750Th.',
#        '€330Th.', '€100Th.', 'Loan fee:€50Th.', '€42.95m', '€22.00m',
#        '€16.00m', 'Loan fee:€5.00m', 'Loan fee:€200Th.',
#        'Loan fee:€150Th.', '€50Th.', '€1.75m', '€400Th.', '€3.20m',
#        '€47Th.', '€70.00m', '€11.80m', 'Loan fee:€900Th.', '€550Th.',
#        '€332Th.', 'Loan fee:€146Th.', '€30Th.', '€10Th.', '€1.30m',
#        '€276Th.', '€54Th.', '€13.00m', '€5.97m', 'Loan fee:€44Th.',
#        '€20Th.', '€15.40m', '€1.60m', '€1.40m', 'Loan fee:€330Th.',
#        '€34Th.', '€70.65m', '€19.00m', '€120Th.', '€45Th.', '€5.25m',
#        '€375Th.', '€29.50m', '€9.50m', '€3.50m', 'Loan fee:€297Th.',
#        '€45.00m', 'Loan fee:€3.50m', '€2.40m', '€1.10m', '€38Th.',
#        '€25Th.', '€2.90m', '€1.70m', '€800Th.', '€197Th.', '€90Th.',
#        '€17.80m', '€3.60m', '€40Th.', '€1.25m', '€80Th.', '€14.80m',
#        '€6.50m', '€1.17m', 'Loan fee:€14Th.', 'Loan fee:€250Th.', '€300',
#        '€35.00m', '€2.44m', '€62Th.', '€32.60m', '€5.10m', '€172Th.',
#        'Loan fee:€30Th.', '€65.30m', '€20.70m', '€1.96m', '€147Th.',
#        '€125Th.', 'Loan fee:€75Th.', '€5.46m', '€4.55m', '€1.82m',
#        'Loan fee:€455Th.', '€364Th.', '€295Th.', '€764Th.', '€546Th.',
#        '€227Th.', '€130Th.', '€32.00m', '€9.09m', '€3.90m', '€2.85m',
#        'Loan fee:€205Th.', '€78Th.', '€11.90m', '€610Th.', '€26.00m',
#        '€68Th.', '€5.23m', '€3.64m', '€2.80m', '€2.70m',
#        'Loan fee:€1.40m', '€637Th.', '€24.00m', '€7.40m', '€1.67m',
#        '€980Th.', '€57.37m', '€18.05m', '€1.73m', '€420Th.', '€70Th.',
#        '€36.00m', '€590Th.', '€220Th.', '€773Th.', '€16.35m', '€14.50m',
#        '€10.50m', '€7.70m', '€3.80m', '€835Th.', 'Loan fee:€196Th.',
#        '€4.68m', '€41.00m', '€9.40m', '€7.50m', '€470Th.', '€296Th.',
#        '€67.00m', '€14.70m', '€4.70m', '€1.88m', '€273Th.', '€56Th.',
#        '€13.50m', '€950Th.', '€38.00m', '€245Th.', '€12.50m', '€850Th.',
#        '€818Th.', '€430Th.', '€1.19m', '€380Th.', '€58.00m', '€56.20m',
#        '€14.00m', '€10.10m', '€455Th.', '€24.30m', '€6.70m', '€909Th.',
#        '€154Th.', '€75Th.', '€22.60m', '€960Th.', '€379Th.', '€175Th.',
#        'Loan fee:€99Th.', '€15Th.', '€16.50m', '€7.10m', '€3.70m',
#        '€955Th.', '€31.25m', '€841Th.', '€394Th.', '€284Th.', '€65Th.',
#        '€57Th.', 'Loan fee:', '€25.00m', '€10.65m', '€9.55m', '€3.45m',
#        '€3.35m', '€1.09m', '€689Th.', '€613Th.', '€495Th.', '€440Th.',
#        '€355Th.', '€196Th.', '€136Th.', '€31.00m', '€21.00m', '€12.30m',
#        '€9.80m', '€414Th.', '€936Th.', 'Loan fee:€750Th.', '€650Th.',
#        '€149Th.', '€52.20m', '€49.00m', '€8.20m', '€180Th.', '€171Th.',
#        '€91Th.', '€240Th.', '€97Th.', '€5.80m', '€480Th.', '€320Th.',
#        '€80.00m', '€75.00m', '€60.00m', '€41.50m', '€40.00m', '€37.00m',
#        '€32.84m', '€30.00m', '€29.20m', '€23.60m', '€20.50m', '€18.50m',
#        '€16.70m', '€15.30m', '€11.60m', '€11.50m', '€9.30m', '€8.40m',
#        'Loan fee:€8.00m', '€7.30m', '€6.40m', '€6.36m', '€5.90m',
#        '€5.70m', '€5.45m', '€4.90m', '€4.80m', '€4.75m', '€4.35m',
#        '€4.30m', '€4.25m', '€3.85m', '€3.30m', '€3.25m', '€2.73m',
#        '€2.36m', '€2.10m', '€1.89m', '€1.53m', '€1.14m', '€1.08m',
#        '€870Th.', '€672Th.', '€670Th.', '€636Th.', '€615Th.', '€575Th.',
#        'Loan fee:€570Th.', '€530Th.', '€510Th.', '€465Th.', '€310Th.',
#        '€281Th.', '€280Th.', '€260Th.', '€215Th.', '€210Th.',
#        'Loan fee:€190Th.', '€190Th.', '€170Th.', '€167Th.', '€160Th.',
#        '€135Th.', 'Loan fee:€120Th.', '€115Th.', '€110Th.', '€108Th.',
#        '€85Th.', '€58Th.', '€26Th.', '€23Th.', '€22Th.', '€18Th.',
#        '€17Th.', '€14Th.', '€12Th.', 'draft'], dtype=object)

# %% [markdown]
# There are unique data types in the 'cost' column, such as those containing 'Loan fee:' and 'draft'. These activities do not potray the purchase of a player by a club. Thus, these data types can not be included.

# %%
## Cost
df=df[df["cost"].str.contains("Loan fee")==False]
df=df[df["cost"].str.contains("-")==False]
df=df[df["cost"].str.contains("\?")==False]
df=df[df["cost"].str.contains("loan transfer")==False]
df=df[df["cost"].str.contains("draft")==False]

df["cost"]=df["cost"].str.replace("free transfer","0")
df["cost"]=df["cost"].str.replace("Th.","000")
df["cost"]=df["cost"].str.replace("m","0000")
df["cost"]=df["cost"].str.replace(".","")
df["cost"]=df["cost"].str.replace("€","")

df["cost"]=df["cost"].astype(int)

## Player Value
df=df[df["player_valuje"].str.contains("Loan fee")==False]
df=df[df["player_valuje"].str.contains("-")==False]
df=df[df["player_valuje"].str.contains("\?")==False]
df=df[df["player_valuje"].str.contains("loan transfer")==False]
df=df[df["player_valuje"].str.contains("draft")==False]

df["player_valuje"]=df["player_valuje"].str.replace("free transfer","0")
df["player_valuje"]=df["player_valuje"].str.replace("Th.","000")
df["player_valuje"]=df["player_valuje"].str.replace("m","0000")
df["player_valuje"]=df["player_valuje"].str.replace(".","")
df["player_valuje"]=df["player_valuje"].str.replace("€","")

df["player_valuje"]=df["player_valuje"].astype(int)

## Rename column
df = df.rename(columns = {'player_valuje':'player_market_value'})
# Out:
# <ipython-input-6-ef9ee5adbb8d>:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["cost"]=df["cost"].str.replace("Th.","000")
# <ipython-input-6-ef9ee5adbb8d>:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["cost"]=df["cost"].str.replace(".","")
# <ipython-input-6-ef9ee5adbb8d>:24: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["player_valuje"]=df["player_valuje"].str.replace("Th.","000")
# <ipython-input-6-ef9ee5adbb8d>:26: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["player_valuje"]=df["player_valuje"].str.replace(".","")

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19139 entries, 0 to 26356
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 19139 non-null  object
#  1   position             19138 non-null  object
#  2   age                  19067 non-null  float64
#  3   origin_club          19139 non-null  object
#  4   league_origin_club   18989 non-null  object
#  5   country_origin_club  18989 non-null  object
#  6   new_club             19139 non-null  object
#  7   league_new_club      18971 non-null  object
#  8   country_new_club     18971 non-null  object
#  9   player_market_value  19139 non-null  int64
#  10  cost                 19139 non-null  int64
#  11  date_of_transfer     19139 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 1.9+ MB
#             name          position   age        origin_club  \
# 0   Amine Gouiri    Centre-Forward  22.0           OGC Nice
# 1     Umar Sadiq    Centre-Forward  25.0         UD Almería
# 2   Carlos Soler  Central Midfield  25.0        Valencia CF
# 3  Manuel Akanji       Centre-Back  27.0  Borussia Dortmund
# 4      Wout Faes       Centre-Back  24.0        Stade Reims
#
#   league_origin_club country_origin_club             new_club league_new_club  \
# 0            Ligue 1              France     Stade Rennais FC         Ligue 1
# 1             LaLiga               Spain        Real Sociedad          LaLiga
# 2             LaLiga               Spain  Paris Saint-Germain         Ligue 1
# 3         Bundesliga             Germany      Manchester City  Premier League
# 4            Ligue 1              France       Leicester City  Premier League
#
#   country_new_club  player_market_value      cost date_of_transfer
# 0           France             42000000  28000000       2022-09-01
# 1            Spain             18000000  20000000       2022-09-01
# 2           France             50000000  18000000       2022-09-01
# 3          England             30000000  17500000       2022-09-01
# 4          England             10000000  17000000       2022-09-01

# %%
coord=pd.read_html("https://developers.google.com/public-data/docs/canonical/countries_csv")[0]
new_count = [{'country': 'EN', 'latitude': 52.3555177, 'longitude': -1.1743197,'name':'England'},
             {'country': 'W', 'latitude': 53.3406, 'longitude': -1.2816,'name':'Wales'},
             {'country': 'H', 'latitude': 22.396428, 'longitude': 114.109497,'name':'Hongkong'},
             {'country': 'BH', 'latitude': 43.856430, 'longitude': 18.413029,'name':'Bosnia-Herzegovina'},
             {'country': 'NM', 'latitude': 41.6086, 'longitude': 41.6086,'name':'North Macedonia'},
             {'country': 'NI', 'latitude': 54.607868, 'longitude': -5.926437,'name':'Northern Ireland'},
             {'country': 'PA', 'latitude': 31.952162, 'longitude': 35.233154,'name':'Palästina'},
             {'country': 'CI', 'latitude': 7.539989, 'longitude': -5.547080,'name':"Cote d'Ivoire"},
             {'country': 'TG', 'latitude': 13.598878, 'longitude': -14.947733,'name':'The Gambia'},
             {'country': 'CT', 'latitude': 25.105497, 'longitude': 121.597366,'name':'Chinese Taipei'},
             {'country': 'MY', 'latitude': 16.871311, 'longitude': 96.199379,'name':'Myanmar'},
             {'country': 'CO', 'latitude': -4.322447, 'longitude': 15.307045,'name':'Congo'},
             {'country': 'ES', 'latitude': -26.522503, 'longitude': 31.465866,'name':'Eswatini'},
             {'country': 'NK', 'latitude': -22.275801, 'longitude': 166.457993,'name':'Neukaledonien'},
             {'country': 'CT', 'latitude': 23.697810, 'longitude': 120.960515,'name':'Chinese Taipei (Taiwan)'},
             {'country': 'SC', 'latitude': 56.0000, 'longitude': -4,'name':'Scotland'},
             {'country': 'DRC', 'latitude':-4.322447, 'longitude': 15.307045,'name':'DR Congo'},
             {'country': 'BO', 'latitude': -24.653257, 'longitude': 25.906792,'name':'Botsuana'},
             {'country': 'KS', 'latitude': 35.9078, 'longitude': 127.7669,'name':'Korea, South'}]

coord = pd.concat([coord,pd.DataFrame(new_count)])
coord_from=coord.rename(columns={"name": "from", "longitude": "longitude_from","latitude":"latitude_from"}).drop(['country'], axis=1)
coord_to=coord.rename(columns={"name": "to", "longitude": "longitude_to","latitude":"latitude_to"}).drop(['country'], axis=1)

# %%
df=df.merge(coord_to, left_on='country_new_club',right_on='to', how='left')
df=df.merge(coord_from, left_on='country_origin_club',right_on='from', how='left')
df['week_of_transfer'] = pd.to_datetime(df['date_of_transfer']).dt.week
# Out:
# <ipython-input-9-17a25b8393c4>:3: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['week_of_transfer'] = pd.to_datetime(df['date_of_transfer']).dt.week

# %%
## Backup data
df.to_csv('transfer_market_raw_data.csv',index=False)

# %%
## Check Data after Longitude & Lattitude Merge
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19139 entries, 0 to 19138
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   name                 19139 non-null  object
#  1   position             19138 non-null  object
#  2   age                  19067 non-null  float64
#  3   origin_club          19139 non-null  object
#  4   league_origin_club   18989 non-null  object
#  5   country_origin_club  18989 non-null  object
#  6   new_club             19139 non-null  object
#  7   league_new_club      18971 non-null  object
#  8   country_new_club     18971 non-null  object
#  9   player_market_value  19139 non-null  int64
#  10  cost                 19139 non-null  int64
#  11  date_of_transfer     19139 non-null  object
#  12  latitude_to          18971 non-null  float64
#  13  longitude_to         18971 non-null  float64
#  14  to                   18971 non-null  object
#  15  latitude_from        18989 non-null  float64
#  16  longitude_from       18989 non-null  float64
#  17  from                 18989 non-null  object
#  18  week_of_transfer     19139 non-null  int64
# dtypes: float64(5), int64(3), object(11)
# memory usage: 2.9+ MB
#             name          position   age        origin_club  \
# 0   Amine Gouiri    Centre-Forward  22.0           OGC Nice
# 1     Umar Sadiq    Centre-Forward  25.0         UD Almería
# 2   Carlos Soler  Central Midfield  25.0        Valencia CF
# 3  Manuel Akanji       Centre-Back  27.0  Borussia Dortmund
# 4      Wout Faes       Centre-Back  24.0        Stade Reims
#
#   league_origin_club country_origin_club             new_club league_new_club  \
# 0            Ligue 1              France     Stade Rennais FC         Ligue 1
# 1             LaLiga               Spain        Real Sociedad          LaLiga
# 2             LaLiga               Spain  Paris Saint-Germain         Ligue 1
# 3         Bundesliga             Germany      Manchester City  Premier League
# 4            Ligue 1              France       Leicester City  Premier League
#
#   country_new_club  player_market_value      cost date_of_transfer  \
# 0           France             42000000  28000000       2022-09-01
# 1            Spain             18000000  20000000       2022-09-01
# 2           France             50000000  18000000       2022-09-01
# 3          England             30000000  17500000       2022-09-01
# 4          England             10000000  17000000       2022-09-01
#
#    latitude_to  longitude_to       to  latitude_from  longitude_from     from  \
# 0    46.227638      2.213749   France      46.227638        2.213749   France
# 1    40.463667     -3.749220    Spain      40.463667       -3.749220    Spain
# 2    46.227638      2.213749   France      40.463667       -3.749220    Spain
# 3    52.355518     -1.174320  England      51.165691       10.451526  Germany
# 4    52.355518     -1.174320  England      46.227638        2.213749   France
#
#    week_of_transfer
# 0                35
# 1                35
# 2                35
# 3                35
# 4                35

# %% [markdown]
# ## 3. Data Exploration & Analysis

# %%
df.groupby(['country_origin_club']).agg({'name':'count'}).sort_values(by='name',ascending=False).head(20)
# Out:
#                      name
# country_origin_club
# Italy                2895
# Spain                1795
# Germany              1145
# Russia                828
# France                575
# Serbia                540
# Romania               528
# Turkey                523
# England               519
# Greece                502
# Iran                  453
# Bosnia-Herzegovina    393
# Portugal              372
# Netherlands           304
# Bulgaria              291
# Switzerland           261
# Hungary               259
# Thailand              254
# Poland                239
# Ukraine               224

# %%
pd.to_datetime(df['date_of_transfer'].unique())
# Out:
# DatetimeIndex(['2022-09-01', '2022-08-31', '2022-08-30', '2022-08-29',
#                '2022-08-28', '2022-08-27', '2022-08-26', '2022-08-25',
#                '2022-08-24', '2022-08-23', '2022-08-22', '2022-08-21',
#                '2022-08-20', '2022-08-19', '2022-08-18', '2022-08-17',
#                '2022-08-16', '2022-08-15', '2022-08-14', '2022-08-13',
#                '2022-08-12', '2022-08-11', '2022-08-10', '2022-08-09',
#                '2022-08-08', '2022-08-07', '2022-08-06', '2022-08-05',
#                '2022-08-04', '2022-08-03', '2022-08-02', '2022-08-01',
#                '2022-07-31', '2022-07-30', '2022-07-29', '2022-07-28',
#                '2022-07-27', '2022-07-26', '2022-07-25', '2022-07-24',
#                '2022-07-23', '2022-07-22', '2022-07-21', '2022-07-20',
#                '2022-07-19', '2022-07-18', '2022-07-17', '2022-07-16',
#                '2022-07-15', '2022-07-14', '2022-07-13', '2022-07-12',
#                '2022-07-11', '2022-07-10', '2022-07-09', '2022-07-08',
#                '2022-07-07', '2022-07-06', '2022-07-05', '2022-07-04',
#                '2022-07-03', '2022-07-02', '2022-07-01'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ### 3.1 Top 10 Most Exspensive Transfers & Most Valueable Players of Summer 2022 Transfer Window

# %%
list(df.columns)
# Out:
# ['name',
#  'position',
#  'age',
#  'origin_club',
#  'league_origin_club',
#  'country_origin_club',
#  'new_club',
#  'league_new_club',
#  'country_new_club',
#  'player_market_value',
#  'cost',
#  'date_of_transfer',
#  'latitude_to',
#  'longitude_to',
#  'to',
#  'latitude_from',
#  'longitude_from',
#  'from',
#  'week_of_transfer']

# %%
df[['name','age','position','origin_club','new_club','cost']].sort_values(by='cost',ascending= False).head(10)
# Out:
#                       name   age            position             origin_club  \
# 502                 Antony  22.0        Right Winger          Ajax Amsterdam
# 274          Wesley Fofana  21.0         Centre-Back          Leicester City
# 12364  Aurélien Tchouameni  22.0  Defensive Midfield               AS Monaco
# 12365         Darwin Núñez  23.0      Centre-Forward              SL Benfica
# 1496              Casemiro  30.0  Defensive Midfield             Real Madrid
# 899         Alexander Isak  22.0      Centre-Forward           Real Sociedad
# 7871      Matthijs de Ligt  22.0         Centre-Back             Juventus FC
# 3792        Marc Cucurella  24.0           Left-Back  Brighton & Hove Albion
# 12366       Erling Haaland  21.0      Centre-Forward       Borussia Dortmund
# 12367          Richarlison  25.0      Centre-Forward              Everton FC
#
#                 new_club      cost
# 502    Manchester United  95000000
# 274           Chelsea FC  80400000
# 12364        Real Madrid  80000000
# 12365       Liverpool FC  75000000
# 1496   Manchester United  70650000
# 899     Newcastle United  70000000
# 7871       Bayern Munich  67000000
# 3792          Chelsea FC  65300000
# 12366    Manchester City  60000000
# 12367  Tottenham Hotspur  58000000

# %%
# Top 10 Most Expensive Transfers & Most Valueable Players
top_transfers = df[['name','position','age','cost']].sort_values(by='cost', ascending = False).reset_index().head(10)
# top_value = df.sort_values(by='player_market_value', ascending = False).reset_index().head(10)

# %%
top_transfers['Transfer Cost'] = ['€ {:,.2f}'.format(i) for i in list(top_transfers['cost'])]
res1 = top_transfers[['name','Transfer Cost']].rename(columns={'name':'Player Name'})
res1.index += 1
res1
# Out:
#             Player Name    Transfer Cost
# 1                Antony  € 95,000,000.00
# 2         Wesley Fofana  € 80,400,000.00
# 3   Aurélien Tchouameni  € 80,000,000.00
# 4          Darwin Núñez  € 75,000,000.00
# 5              Casemiro  € 70,650,000.00
# 6        Alexander Isak  € 70,000,000.00
# 7      Matthijs de Ligt  € 67,000,000.00
# 8        Marc Cucurella  € 65,300,000.00
# 9        Erling Haaland  € 60,000,000.00
# 10          Richarlison  € 58,000,000.00

# %%
## Plot Top 10
fig, axis = plt.subplots(figsize = (6,7))
plt.subplots_adjust(left=0.1,
                    bottom=0.1,
                    right=0.9,
                    top=1,
                    wspace=0.4,
                    hspace=0.8)

top_transfers.plot.barh(x = 'name', y = 'cost', color = 'cyan', ax = axis)
# top_value.plot.barh(x = 'name', y = 'player_market_value', color = 'r', ax = axis[1])

axis.set_title('Top 10 Most Expensive Transfers of Summer 2022', fontsize = 14)
axis.set_ylabel('Player Name',fontsize = 11, labelpad = 5)
axis.set_xlabel('Amount €',fontsize = 11, labelpad = 7)
axis.invert_yaxis()

# for i in range(len(top_transfers['cost'])):
#         plt.text(i, top_transfers['name'][i]//2, top_transfers['cost'][i], ha = 'center')

axis.ticklabel_format(useOffset=False, style='plain')
plt.savefig("top_10_transfers.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in ticklabel_format(self, axis, style, scilimits, useOffset, useLocale, useMathText)
#    3259                 if is_sci_style is not None:
# -> 3260                     axis.major.formatter.set_scientific(is_sci_style)
#    3261                 if scilimits is not None:
#
# AttributeError: 'FuncFormatter' object has no attribute 'set_scientific'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-167c0f469d01> in <cell line: 21>()
#      19 #         plt.text(i, top_transfers['name'][i]//2, top_transfers['cost'][i], ha = 'center')
#      20
# ---> 21 axis.ticklabel_format(useOffset=False, style='plain')
#      22 plt.savefig("top_10_transfers.png")
#      23 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in ticklabel_format(self, axis, style, scilimits, useOffset, useLocale, useMathText)
#    3268                     axis.major.formatter.set_useMathText(useMathText)
#    3269         except AttributeError as err:
# -> 3270             raise AttributeError(
#    3271                 "This method only works with the ScalarFormatter") from err
#    3272
#
# AttributeError: This method only works with the ScalarFormatter

# %% [markdown]
# ### 3.2 Visualizing Transfer Activity per Country & League

# %%
df.info()

# %%
### Top 10 Leagues for Money Spent in Transfer Market by Composition

top10_spent = df[df['cost'] != 0].groupby(['league_new_club','country_new_club']).agg({'cost':'sum'}).sort_values(by='cost',ascending=False).head(5)
top10_spent = top10_spent.reset_index()
top10_spent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   league_new_club   5 non-null      object
#  1   country_new_club  5 non-null      object
#  2   cost              5 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 248.0+ bytes

# %%
top10_spent
# Out:
#   league_new_club country_new_club        cost
# 0  Premier League          England  2219460000
# 1         Serie A            Italy   705830000
# 2         Ligue 1           France   510800000
# 3          LaLiga            Spain   502690000
# 4      Bundesliga          Germany   479830000

# %%
## Most Expensive Player Transfer per Top 5 League with the Most Money Spent

lst = df[df['league_new_club'].isin(list(top10_spent['league_new_club']))].sort_values(by=['league_new_club','cost'], ascending = [False, False])
lst.head(10)
# Out:
#                        name            position   age          origin_club  \
# 7560                 Bremer         Centre-Back  25.0            Torino FC
# 12369       Federico Chiesa        Right Winger  24.0       ACF Fiorentina
# 4474   Charles De Ketelaere  Attacking Midfield  21.0       Club Brugge KV
# 12379        Joaquín Correa      Second Striker  27.0             SS Lazio
# 12380          Jérémie Boga         Left Winger  25.0          US Sassuolo
# 11234               Éderson    Central Midfield  22.0  US Salernitana 1919
# 12383         Merih Demiral         Centre-Back  24.0          Juventus FC
# 1497         Hassane Kamara           Left-Back  28.0           Watford FC
# 5973            Min-jae Kim         Centre-Back  25.0        Fenerbahce SK
# 806          Rasmus Höjlund      Centre-Forward  19.0        SK Sturm Graz
#
#        league_origin_club country_origin_club        new_club league_new_club  \
# 7560              Serie A               Italy     Juventus FC         Serie A
# 12369             Serie A               Italy     Juventus FC         Serie A
# 4474   Jupiler Pro League             Belgium        AC Milan         Serie A
# 12379             Serie A               Italy     Inter Milan         Serie A
# 12380             Serie A               Italy     Atalanta BC         Serie A
# 11234             Serie A               Italy     Atalanta BC         Serie A
# 12383             Serie A               Italy     Atalanta BC         Serie A
# 1497         Championship             England  Udinese Calcio         Serie A
# 5973            Süper Lig              Turkey      SSC Napoli         Serie A
# 806            Bundesliga             Austria     Atalanta BC         Serie A
#
#       country_new_club  player_market_value      cost date_of_transfer  \
# 7560             Italy             35000000  41000000       2022-07-20
# 12369            Italy             65000000  40000000       2022-07-01
# 4474             Italy             30000000  32000000       2022-08-02
# 12379            Italy             23000000  23600000       2022-07-01
# 12380            Italy             19000000  22000000       2022-07-01
# 11234            Italy             13000000  21000000       2022-07-06
# 12383            Italy             25000000  20000000       2022-07-01
# 1497             Italy              4000000  19000000       2022-08-22
# 5973             Italy             14000000  18050000       2022-07-27
# 806              Italy              4500000  17000000       2022-08-27
#
#        latitude_to  longitude_to     to  latitude_from  longitude_from  \
# 7560      41.87194      12.56738  Italy      41.871940       12.567380
# 12369     41.87194      12.56738  Italy      41.871940       12.567380
# 4474      41.87194      12.56738  Italy      50.503887        4.469936
# 12379     41.87194      12.56738  Italy      41.871940       12.567380
# 12380     41.87194      12.56738  Italy      41.871940       12.567380
# 11234     41.87194      12.56738  Italy      41.871940       12.567380
# 12383     41.87194      12.56738  Italy      41.871940       12.567380
# 1497      41.87194      12.56738  Italy      52.355518       -1.174320
# 5973      41.87194      12.56738  Italy      38.963745       35.243322
# 806       41.87194      12.56738  Italy      47.516231       14.550072
#
#           from  week_of_transfer
# 7560     Italy                29
# 12369    Italy                26
# 4474   Belgium                31
# 12379    Italy                26
# 12380    Italy                26
# 11234    Italy                27
# 12383    Italy                26
# 1497   England                34
# 5973    Turkey                30
# 806    Austria                34

# %%
lst = lst[lst['country_new_club'].isin(['England','Italy','France','Germany','Spain'])].drop_duplicates(subset= ['league_new_club','country_new_club'],keep='first')
lst[['league_new_club','name','position','origin_club','new_club','age','position','date_of_transfer']]
# Out:
#       league_new_club                 name            position  \
# 7560          Serie A               Bremer         Centre-Back
# 502    Premier League               Antony        Right Winger
# 12368         Ligue 1              Vitinha    Central Midfield
# 12364          LaLiga  Aurélien Tchouameni  Defensive Midfield
# 7871       Bundesliga     Matthijs de Ligt         Centre-Back
#
#           origin_club             new_club   age            position  \
# 7560        Torino FC          Juventus FC  25.0         Centre-Back
# 502    Ajax Amsterdam    Manchester United  22.0        Right Winger
# 12368        FC Porto  Paris Saint-Germain  22.0    Central Midfield
# 12364       AS Monaco          Real Madrid  22.0  Defensive Midfield
# 7871      Juventus FC        Bayern Munich  22.0         Centre-Back
#
#       date_of_transfer
# 7560        2022-07-20
# 502         2022-08-30
# 12368       2022-07-01
# 12364       2022-07-01
# 7871        2022-07-19

# %%
labels = list(top10_spent['league_new_club'])
sizes = top10_spent['cost']

fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(aspect="equal"))

def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n(€ {:,.2f} )".format(pct, absolute)

wedges, texts, autotexts = ax.pie(sizes, autopct=lambda pct: func(pct, sizes),
                                  textprops=dict(color="w"))

ax.legend(wedges, labels,
          title="Football Leagues",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=10)

ax.set_title("Top 5 Leagues for Money Spent in Summer 2022 Transfer Market", fontsize=14, loc = 'right')

plt.show()

# %% [markdown]
# ### 3.3 Number of Transfer Activity Day-to-Day During Summer 2022 Transfer Window

# %%
activity = df[df['league_new_club'].isin(list(top10_spent['league_new_club']))]
activity.head(10)
# Out:
#                         name            position   age  \
# 0               Amine Gouiri      Centre-Forward  22.0
# 1                 Umar Sadiq      Centre-Forward  25.0
# 2               Carlos Soler    Central Midfield  25.0
# 3              Manuel Akanji         Centre-Back  27.0
# 4                  Wout Faes         Centre-Back  24.0
# 5         Leander Dendoncker  Defensive Midfield  27.0
# 6             Gaëtan Laborde      Centre-Forward  28.0
# 7  Pierre-Emerick Aubameyang      Centre-Forward  33.0
# 8       Jörgen Strand Larsen      Centre-Forward  22.0
# 9              Billy Gilmour    Central Midfield  21.0
#
#                origin_club league_origin_club country_origin_club  \
# 0                 OGC Nice            Ligue 1              France
# 1               UD Almería             LaLiga               Spain
# 2              Valencia CF             LaLiga               Spain
# 3        Borussia Dortmund         Bundesliga             Germany
# 4              Stade Reims            Ligue 1              France
# 5  Wolverhampton Wanderers     Premier League             England
# 6         Stade Rennais FC            Ligue 1              France
# 7             FC Barcelona             LaLiga               Spain
# 8             FC Groningen         Eredivisie         Netherlands
# 9               Chelsea FC     Premier League             England
#
#                  new_club league_new_club country_new_club  \
# 0        Stade Rennais FC         Ligue 1           France
# 1           Real Sociedad          LaLiga            Spain
# 2     Paris Saint-Germain         Ligue 1           France
# 3         Manchester City  Premier League          England
# 4          Leicester City  Premier League          England
# 5             Aston Villa  Premier League          England
# 6                OGC Nice         Ligue 1           France
# 7              Chelsea FC  Premier League          England
# 8           Celta de Vigo          LaLiga            Spain
# 9  Brighton & Hove Albion  Premier League          England
#
#    player_market_value      cost date_of_transfer  latitude_to  longitude_to  \
# 0             42000000  28000000       2022-09-01    46.227638      2.213749
# 1             18000000  20000000       2022-09-01    40.463667     -3.749220
# 2             50000000  18000000       2022-09-01    46.227638      2.213749
# 3             30000000  17500000       2022-09-01    52.355518     -1.174320
# 4             10000000  17000000       2022-09-01    52.355518     -1.174320
# 5             28000000  15000000       2022-09-01    52.355518     -1.174320
# 6             18000000  15000000       2022-09-01    46.227638      2.213749
# 7             15000000  12000000       2022-09-01    52.355518     -1.174320
# 8              6000000  11000000       2022-09-01    40.463667     -3.749220
# 9             12000000  10400000       2022-09-01    52.355518     -1.174320
#
#         to  latitude_from  longitude_from         from  week_of_transfer
# 0   France      46.227638        2.213749       France                35
# 1    Spain      40.463667       -3.749220        Spain                35
# 2   France      40.463667       -3.749220        Spain                35
# 3  England      51.165691       10.451526      Germany                35
# 4  England      46.227638        2.213749       France                35
# 5  England      52.355518       -1.174320      England                35
# 6   France      46.227638        2.213749       France                35
# 7  England      40.463667       -3.749220        Spain                35
# 8    Spain      52.132633        5.291266  Netherlands                35
# 9  England      52.355518       -1.174320      England                35

# %%
activity1 = activity.groupby(['league_new_club','date_of_transfer','country_new_club']).agg({'name':'count','cost':'sum'}).reset_index()
activity1.info()
activity1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   league_new_club   258 non-null    object
#  1   date_of_transfer  258 non-null    object
#  2   country_new_club  258 non-null    object
#  3   name              258 non-null    int64
#  4   cost              258 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 10.2+ KB
#   league_new_club date_of_transfer country_new_club  name       cost
# 0      Bundesliga       2022-07-01          Austria    36   22300000
# 1      Bundesliga       2022-07-01          Germany    74  232330000
# 2      Bundesliga       2022-07-02          Germany     2    7000000
# 3      Bundesliga       2022-07-04          Germany     1          0
# 4      Bundesliga       2022-07-05          Austria     1    1000000

# %%
list(top10_spent['league_new_club'])

# %%
activity2 = activity1[activity1['league_new_club'] == 'LaLiga']

fig=plt.figure(figsize=(24,5))
ax1=plt.subplot(1,1,1)
ax1.bar(activity2['date_of_transfer'],activity2['name'],width=0.6,color='grey')
#Rotate x-axis labels to make them more legible
for xlabel in ax1.get_xticklabels():
    xlabel.set_rotation(-30)

ax1.set_xlabel('Date of Transfer')
ax1.set_ylabel('Number of Transfer Activities')

plt.axvline(x='2022-07-01',ls='--', color='g', label='Start of Transfer Window')
plt.axvline(x='2022-08-25',ls='--', color='y', label='One Week Before Transfer Deadline Day')
plt.axvline(x='2022-09-01',ls='--', color='r', label='Summer 2022 Transfer Deadline Day')
plt.legend(bbox_to_anchor=(1.0, 1), loc=6)

plt.title('Daily Number of Player Transfer Activity from LaLiga', fontsize = 12)
# Out:
# Text(0.5, 1.0, 'Daily Number of Player Transfer Activity from LaLiga')
