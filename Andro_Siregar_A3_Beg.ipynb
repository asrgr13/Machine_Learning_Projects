# %% [markdown]
# ## Data Pre-Processing

# %%
# import the cancer patient data
import pandas as pd

cancer_data  = pd.read_csv("https://raw.githubusercontent.com/dphi-official/Datasets/master/cancer_death_rate/Training_set_label.csv" )

# %%
cancer_data.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  ...  BirthRate  TARGET_deathRate
# 0         19.0                 8  ...  15.157116             160.3
# 1         88.0                34  ...   3.293510             194.9
# 2        195.0                83  ...   6.390328             196.5
# 3        116.0                55  ...   5.124836             230.9
# 4         80.0                35  ...   3.897033             162.2
#
# [5 rows x 34 columns]

# %%
cancer_data['Geography'].describe()
# Out:
# count                       3051
# unique                      2285
# top       Miller County, Georgia
# freq                           2
# Name: Geography, dtype: object

# %%
# Test data for predictions using model
test_data = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/cancer_death_rate/Testing_set_label.csv')

# %%
# Drop binnedInc and Geography. Testing model accuracy without said variables
cancer_drop = cancer_data.drop(columns=['binnedInc','Geography'])
test_drop = test_data.drop(columns=['binnedInc','Geography'])

# %%
# Checking correlations between variables 
import seaborn as sns

#cdata_corr_matrix = cancer_data.corr()
cdata_corr_matrix = cancer_drop.corr()
sns.heatmap(data=cdata_corr_matrix, annot=False)

# %%
# Correlation coefficients between target and every variable
cdata_corr_matrix['TARGET_deathRate'].sort_values(ascending=False)
# Out:
# TARGET_deathRate           1.000000
# incidenceRate              0.467683
# PctPublicCoverageAlone     0.456804
# povertyPercent             0.427118
# PctPublicCoverage          0.422291
# PctHS25_Over               0.403449
# PctUnemployed16_Over       0.379085
# PctHS18_24                 0.284328
# PctBlack                   0.250954
# PctNoHS18_24               0.075815
# MedianAgeFemale            0.034693
# MedianAge                  0.002772
# MedianAgeMale             -0.002006
# studyPerCap               -0.023890
# AvgHouseholdSize          -0.030288
# avgDeathsPerYear          -0.074008
# BirthRate                 -0.088322
# popEst2015                -0.111470
# avgAnnCount               -0.130745
# PctWhite                  -0.173265
# PctOtherRace              -0.189210
# PctAsian                  -0.202352
# PctSomeCol18_24           -0.206337
# PctEmpPrivCoverage        -0.257117
# PercentMarried            -0.262946
# PctBachDeg18_24           -0.292220
# PctMarriedHouseholds      -0.298414
# PctPrivateCoverageAlone   -0.364386
# PctPrivateCoverage        -0.382859
# PctEmployed16_Over        -0.414695
# medIncome                 -0.433311
# PctBachDeg25_Over         -0.480939
# Name: TARGET_deathRate, dtype: float64

# %%
# Checking null values in the dataset
cancer_drop.isnull().sum()
# Out:
# avgAnnCount                   0
# avgDeathsPerYear              0
# incidenceRate                 0
# medIncome                     0
# popEst2015                    0
# povertyPercent                0
# studyPerCap                   0
# MedianAge                     0
# MedianAgeMale                 0
# MedianAgeFemale               0
# AvgHouseholdSize              0
# PercentMarried                0
# PctNoHS18_24                  0
# PctHS18_24                    0
# PctSomeCol18_24            2266
# PctBachDeg18_24               0
# PctHS25_Over                  0
# PctBachDeg25_Over             0
# PctEmployed16_Over          152
# PctUnemployed16_Over          0
# PctPrivateCoverage            0
# PctPrivateCoverageAlone     604
# PctEmpPrivCoverage            0
# PctPublicCoverage             0
# PctPublicCoverageAlone        0
# PctWhite                      0
# PctBlack                      0
# PctAsian                      0
# PctOtherRace                  0
# PctMarriedHouseholds          0
# BirthRate                     0
# TARGET_deathRate              0
# dtype: int64

# %%
# Filling the null values using either mean or median
import statistics

cancer_1 = cancer_drop[cancer_drop['PctEmployed16_Over'].isnull() == False]
cancer_2 = cancer_drop[cancer_drop['PctPrivateCoverageAlone'].isnull() == False]
cancer_3 = cancer_drop[cancer_drop['PctSomeCol18_24'].isnull() == False]

mean1 = statistics.mean(cancer_1['PctEmployed16_Over'])
mean2 = statistics.mean(cancer_2['PctPrivateCoverageAlone'])
mean3 = statistics.mean(cancer_3['PctSomeCol18_24'])

cancer_drop['PctEmployed16_Over'] = cancer_drop['PctEmployed16_Over'].fillna(mean1)
cancer_drop['PctPrivateCoverageAlone'] = cancer_drop['PctPrivateCoverageAlone'].fillna(mean2)
cancer_drop['PctSomeCol18_24'] = cancer_drop['PctSomeCol18_24'].fillna(mean3)
cancer_drop.isnull().sum()
# Out:
# avgAnnCount                0
# avgDeathsPerYear           0
# incidenceRate              0
# medIncome                  0
# popEst2015                 0
# povertyPercent             0
# studyPerCap                0
# MedianAge                  0
# MedianAgeMale              0
# MedianAgeFemale            0
# AvgHouseholdSize           0
# PercentMarried             0
# PctNoHS18_24               0
# PctHS18_24                 0
# PctSomeCol18_24            0
# PctBachDeg18_24            0
# PctHS25_Over               0
# PctBachDeg25_Over          0
# PctEmployed16_Over         0
# PctUnemployed16_Over       0
# PctPrivateCoverage         0
# PctPrivateCoverageAlone    0
# PctEmpPrivCoverage         0
# PctPublicCoverage          0
# PctPublicCoverageAlone     0
# PctWhite                   0
# PctBlack                   0
# PctAsian                   0
# PctOtherRace               0
# PctMarriedHouseholds       0
# BirthRate                  0
# TARGET_deathRate           0
# dtype: int64

# %% [markdown]
# ## Splitting Data into Train and Test Datasets

# %%
# Seperate independent and dependent variables
X = cancer_drop.drop(columns=['TARGET_deathRate'])
y = cancer_drop['TARGET_deathRate']

# %%
# import sklearn train test split
from sklearn.model_selection import train_test_split 

# Assign variables to capture train test split output
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ## Modeling Process

# %% [markdown]
# ### Linear Regression Model { Test Data MSE = 345.15277699289896}

# %%
from sklearn.linear_model import LinearRegression

linear_regressor = LinearRegression()  # create object for the class

#fit model to our training data i.e learn coefficients
linear_regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# prints y-intercept
print(linear_regressor.intercept_)

# prints the coefficient
print(linear_regressor.coef_)
# Out:
# 167.29501317737805
# [-3.43671050e-03  1.88124125e-02  2.05633367e-01  2.92573609e-05
#  -1.61966521e-05  2.41802614e-01  2.60007885e-04 -3.69924754e-03
#  -6.34602402e-01 -1.65074350e-01  1.29686679e+00  1.63489893e+00
#  -1.45659219e-01  2.16719346e-01  4.68811452e-02 -1.92397324e-01
#   3.88105055e-01 -8.91836652e-01 -6.63006601e-01  1.60268089e-01
#  -7.02566882e-01  6.07205122e-02  6.39160011e-01  1.86094160e-01
#  -2.31530828e-01 -2.23889074e-01 -1.04586472e-01 -3.54775767e-01
#  -8.88683237e-01 -1.47208436e+00 -6.13695183e-01]

# %%
y_pred = linear_regressor.predict(X_test)  # make predictions

# %%
# importing packages
import numpy as np # to perform calculations 
import pandas as pd # to read data
import matplotlib.pyplot as plt # to visualise

# Comparing model prediction to y_test
plt.plot(X_test, y_test,'rx')
plt.plot(X_test, y_pred, color='black')
plt.show()

# %%
# import metrics library
from sklearn import metrics

#print result of MSE for Test Dataset
print(metrics.mean_squared_error(y_test, y_pred))

#print result of MSE for Train Dataset
print(metrics.mean_squared_error(y_train, linear_regressor.predict(X_train)))

#print result of RMSE 
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 345.1527769928989
# 357.0172099845974
# 18.57828778420926

# %% [markdown]
# ### Linear Regression Model Using High Correlation Variables {Test Data MSE = 361.48539478919383}

# %%
# Correlation coefficients between target and every variable
cdata_corr_matrix['TARGET_deathRate'].sort_values(ascending=False)
# Out:
# TARGET_deathRate           1.000000
# incidenceRate              0.467683
# PctPublicCoverageAlone     0.456804
# povertyPercent             0.427118
# PctPublicCoverage          0.422291
# PctHS25_Over               0.403449
# PctUnemployed16_Over       0.379085
# PctHS18_24                 0.284328
# PctBlack                   0.250954
# PctNoHS18_24               0.075815
# MedianAgeFemale            0.034693
# MedianAge                  0.002772
# MedianAgeMale             -0.002006
# studyPerCap               -0.023890
# AvgHouseholdSize          -0.030288
# avgDeathsPerYear          -0.074008
# BirthRate                 -0.088322
# popEst2015                -0.111470
# avgAnnCount               -0.130745
# PctWhite                  -0.173265
# PctOtherRace              -0.189210
# PctAsian                  -0.202352
# PctSomeCol18_24           -0.206337
# PctEmpPrivCoverage        -0.257117
# PercentMarried            -0.262946
# PctBachDeg18_24           -0.292220
# PctMarriedHouseholds      -0.298414
# PctPrivateCoverageAlone   -0.364386
# PctPrivateCoverage        -0.382859
# PctEmployed16_Over        -0.414695
# medIncome                 -0.433311
# PctBachDeg25_Over         -0.480939
# Name: TARGET_deathRate, dtype: float64

# %%
# Modeling using variables each with highest positive and negative correlation
X_highest = ['incidenceRate','PctPublicCoverageAlone','povertyPercent','PctPublicCoverage','medIncome','PctBachDeg25_Over']
X_used = cancer_drop[X_highest]
X_used.head()
# Out:
#    incidenceRate  PctPublicCoverageAlone  ...  medIncome  PctBachDeg25_Over
# 0          481.5                     9.9  ...      50038               12.2
# 1          486.0                    12.8  ...      59399               16.0
# 2          475.7                    21.6  ...      39721                7.6
# 3          496.6                    33.0  ...      30299                7.0
# 4          372.0                    24.7  ...      39625               10.5
#
# [5 rows x 6 columns]

# %%
# import sklearn train test split
from sklearn.model_selection import train_test_split 

# Assign variables to capture train test split output
X_train1, X_test1, y_train1, y_test1 = train_test_split(X_used, y, test_size=0.1, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

linear_2 = LinearRegression()  # create object for the class

#fit model to our training data i.e learn coefficients
linear_2.fit(X_train1, y_train1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# import metrics library
from sklearn import metrics

#print result of MSE for Test Dataset
print(metrics.mean_squared_error(y_test1, linear_2.predict(X_test1)))

#print result of MSE for Train Dataset
print(metrics.mean_squared_error(y_train1, linear_2.predict(X_train1)))
# Out:
# 361.4853947891938
# 403.66079813364973

# %% [markdown]
# ### Random Forest Model

# %% [markdown]
# Hasil Akurasi (*Mean Squared Error*) :
# * Random Forest(random_state = 2) = 205.55408628641555
# * Random Forest(random_state = 1, max_depth = 5) = 341.7124743908756
# * Random Forest(random_state = 1, max_depth = 10) = 233.603630126049
# * Random Forest(random_state = 2, max_depth = 10) = 231.2713010680097

# %%
# Import Packages
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

# %%
forest = RandomForestRegressor(random_state=2) 
forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=2, verbose=0, warm_start=False)

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score

#print result of MSE
print(metrics.mean_squared_error(y_test, forest.predict(X_test)))
# Out:
# 205.55408628641555

# %% [markdown]
# ### Random Forest with RandomizedSearchCV or GridSearchCV

# %% [markdown]
# GridSearchCV :
#
# parameters = {
#     'max_depth': [10, 20, 50],
#     'bootstrap': [True],
#     'n_estimators': [100, 200, 400],
#     'min_samples_leaf': [3, 4, 5],
#     'min_samples_split': [4, 6, 8],
# }
#
# * Random Forest (random_state = 1)
#   * BEST PARAMS: {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 400}
#   * MSE Train = 62.273675950876026
#   * MSE Test = 217.61683505532503
# * Random Forest (random_state = 2)
#   * BEST PARAMS: {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 400}
#   * MSE Train = 62.40810541486769
#   * MSE Test = 216.82931197693463

# %%
# Function for printing parameters of the best model results from Randomized Search or Grid Search
def print_results(results):
    print('BEST PARAMS: {}\n'.format(results.best_params_))

    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print('{} (+/-{}) for {}'.format(round(mean, 3), round(std * 2, 3), params))

# %%
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV
parameters = {
    'max_depth': [10, 20, 50],
    'bootstrap': [True],
    'n_estimators': [100, 200, 400],
    'min_samples_leaf': [3, 4, 5],
    'min_samples_split': [4, 6, 8],
}
forest_1 = RandomForestRegressor(random_state=1)
forest_2 = RandomForestRegressor(random_state=2)
cv = GridSearchCV(forest_1, parameters, cv=3, n_jobs = -1, verbose = 2)
cv.fit(X_train, y_train)

print_results(cv)
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=-1)]: Done 243 out of 243 | elapsed: 16.9min finished
# BEST PARAMS: {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 400}
#
# 0.616 (+/-0.035) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 100}
# 0.616 (+/-0.032) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 200}
# 0.618 (+/-0.034) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 400}
# 0.616 (+/-0.035) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 100}
# 0.616 (+/-0.032) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 200}
# 0.618 (+/-0.034) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 400}
# 0.612 (+/-0.032) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 100}
# 0.612 (+/-0.03) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 200}
# 0.614 (+/-0.032) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 400}
# 0.608 (+/-0.03) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.61 (+/-0.03) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# 0.611 (+/-0.031) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 400}
# 0.608 (+/-0.03) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 100}
# 0.61 (+/-0.03) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 200}
# 0.611 (+/-0.031) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 400}
# 0.608 (+/-0.03) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 100}
# 0.61 (+/-0.03) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 200}
# 0.611 (+/-0.031) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 400}
# 0.602 (+/-0.027) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.603 (+/-0.026) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 200}
# 0.604 (+/-0.027) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 400}
# 0.602 (+/-0.027) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 100}
# 0.603 (+/-0.026) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 200}
# 0.604 (+/-0.027) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 400}
# 0.602 (+/-0.027) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 100}
# 0.603 (+/-0.026) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 200}
# 0.604 (+/-0.027) for {'bootstrap': True, 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 400}
# 0.628 (+/-0.035) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 100}
# 0.629 (+/-0.031) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 200}
# 0.63 (+/-0.032) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 400}
# 0.628 (+/-0.035) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 100}
# 0.629 (+/-0.031) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 200}
# 0.63 (+/-0.032) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 400}
# 0.623 (+/-0.03) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 100}
# 0.624 (+/-0.028) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 200}
# 0.626 (+/-0.031) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 400}
# 0.618 (+/-0.028) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.62 (+/-0.028) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# 0.622 (+/-0.03) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 400}
# 0.618 (+/-0.028) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 100}
# 0.62 (+/-0.028) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 200}
# 0.622 (+/-0.03) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 400}
# 0.618 (+/-0.028) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 100}
# 0.62 (+/-0.028) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 200}
# 0.622 (+/-0.03) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 400}
# 0.61 (+/-0.027) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.611 (+/-0.026) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 200}
# 0.613 (+/-0.026) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 400}
# 0.61 (+/-0.027) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 100}
# 0.611 (+/-0.026) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 200}
# 0.613 (+/-0.026) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 400}
# 0.61 (+/-0.027) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 100}
# 0.611 (+/-0.026) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 200}
# 0.613 (+/-0.026) for {'bootstrap': True, 'max_depth': 20, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 400}
# 0.628 (+/-0.035) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 100}
# 0.629 (+/-0.031) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 200}
# 0.63 (+/-0.032) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 400}
# 0.628 (+/-0.035) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 100}
# 0.629 (+/-0.031) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 200}
# 0.63 (+/-0.032) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 400}
# 0.623 (+/-0.03) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 100}
# 0.624 (+/-0.028) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 200}
# 0.626 (+/-0.031) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 400}
# 0.618 (+/-0.028) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 100}
# 0.62 (+/-0.028) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 200}
# 0.622 (+/-0.03) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 400}
# 0.618 (+/-0.028) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 100}
# 0.62 (+/-0.028) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 200}
# 0.622 (+/-0.03) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 400}
# 0.618 (+/-0.028) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 100}
# 0.62 (+/-0.028) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 200}
# 0.622 (+/-0.03) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 400}
# 0.61 (+/-0.027) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 100}
# 0.611 (+/-0.026) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 200}
# 0.613 (+/-0.026) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 400}
# 0.61 (+/-0.027) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 100}
# 0.611 (+/-0.026) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 200}
# 0.613 (+/-0.026) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 400}
# 0.61 (+/-0.027) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 100}
# 0.611 (+/-0.026) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 200}
# 0.613 (+/-0.026) for {'bootstrap': True, 'max_depth': 50, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 400}

# %%
from sklearn import metrics

#print result of MSE
print('MSE of Test Data : ',str(metrics.mean_squared_error(y_test, cv.predict(X_test))))
print('MSE of Train Data : ',str(metrics.mean_squared_error(y_train, cv.predict(X_train))))
# Out:
# MSE of Test Data :  217.61683505532503
# MSE of Train Data :  62.273675950876026

# %% [markdown]
# ### Boruta Selector and One Hot Encoding on Geography Variable

# %%
import pandas as pd
cancer_OE = cancer_data
cancer_OE = pd.get_dummies(cancer_OE, columns=['Geography'])
cancer_OE.head()
# Out:
#    avgAnnCount  ...  Geography_Zavala County, Texas
# 0         19.0  ...                               0
# 1         88.0  ...                               0
# 2        195.0  ...                               0
# 3        116.0  ...                               0
# 4         80.0  ...                               0
#
# [5 rows x 2318 columns]

# %%
cancer_data.isnull().sum()
# Out:
# avgAnnCount                   0
# avgDeathsPerYear              0
# incidenceRate                 0
# medIncome                     0
# popEst2015                    0
# povertyPercent                0
# studyPerCap                   0
# binnedInc                     0
# MedianAge                     0
# MedianAgeMale                 0
# MedianAgeFemale               0
# Geography                     0
# AvgHouseholdSize              0
# PercentMarried                0
# PctNoHS18_24                  0
# PctHS18_24                    0
# PctSomeCol18_24            2266
# PctBachDeg18_24               0
# PctHS25_Over                  0
# PctBachDeg25_Over             0
# PctEmployed16_Over          152
# PctUnemployed16_Over          0
# PctPrivateCoverage            0
# PctPrivateCoverageAlone     604
# PctEmpPrivCoverage            0
# PctPublicCoverage             0
# PctPublicCoverageAlone        0
# PctWhite                      0
# PctBlack                      0
# PctAsian                      0
# PctOtherRace                  0
# PctMarriedHouseholds          0
# BirthRate                     0
# TARGET_deathRate              0
# dtype: int64

# %%
# Filling the null values using either mean or median
import statistics

cancer_4 = cancer_OE[cancer_OE['PctEmployed16_Over'].isnull() == False]
cancer_5 = cancer_OE[cancer_OE['PctPrivateCoverageAlone'].isnull() == False]
cancer_6 = cancer_OE[cancer_OE['PctSomeCol18_24'].isnull() == False]

mean4 = statistics.mean(cancer_4['PctEmployed16_Over'])
mean5 = statistics.mean(cancer_5['PctPrivateCoverageAlone'])
mean6 = statistics.mean(cancer_6['PctSomeCol18_24'])

cancer_OE['PctEmployed16_Over'] = cancer_OE['PctEmployed16_Over'].fillna(mean4)
cancer_OE['PctPrivateCoverageAlone'] = cancer_OE['PctPrivateCoverageAlone'].fillna(mean5)
cancer_OE['PctSomeCol18_24'] = cancer_OE['PctSomeCol18_24'].fillna(mean6)

# %%
# Seperate independent and dependent variables
X_OE = cancer_OE.drop(columns=['TARGET_deathRate','binnedInc'])
y_OE = cancer_OE['TARGET_deathRate']

# import sklearn train test split
from sklearn.model_selection import train_test_split 

# Assign variables to capture train test split output
X_train2, X_test2, y_train2, y_test2 = train_test_split(X_OE, y_OE, test_size=0.2, random_state=42)

# %%
# Import Packages
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, f1_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

# %%
forest_OE = RandomForestRegressor(random_state=1) 
forest_OE.fit(X_train2, y_train2)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=1, verbose=0, warm_start=False)

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score

#print result of MSE
print(metrics.mean_squared_error(y_test2, forest_OE.predict(X_test2)))
# Out:
# 245.3315580360066

# %%
import numpy as np

# %%
rfg = RandomForestRegressor(criterion=mse, max_depth=5)
boruta_selector = BorutaPy(rfg, n_estimators='auto', verbose=2, random_state=1)   # initialize the boruta selector
boruta_selector.fit(np.array(X_train), np.array(y_train))       # fitting the boruta selector to get all relavent features.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-36c6576dda5a> in <module>()
#       5 dtg = DecisionTreeRegressor(max_depth=5)
#       6 boruta_selector_2 = BorutaPy(dtg)   # initialize the boruta selector
# ----> 7 boruta_selector_2.fit(np.array(X_train), np.array(y_train))       # fitting the boruta selector to get all relavent features.
#
# /usr/local/lib/python3.6/dist-packages/boruta/boruta_py.py in fit(self, X, y)
#     199         """
#     200
# --> 201         return self._fit(X, y)
#     202
#     203     def transform(self, X, weak=False):
#
# /usr/local/lib/python3.6/dist-packages/boruta/boruta_py.py in _fit(self, X, y)
#     268         # set n_estimators
#     269         if self.n_estimators != 'auto':
# --> 270             self.estimator.set_params(n_estimators=self.n_estimators)
#     271
#     272         # main feature selection loop
#
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py in set_params(self, **params)
#     234                                  'Check the list of available parameters '
#     235                                  'with `estimator.get_params().keys()`.' %
# --> 236                                  (key, self))
#     237
#     238             if delim:
#
# ValueError: Invalid parameter n_estimators for estimator DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=5,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best'). Check the list of available parameters with `estimator.get_params().keys()`.

# %%
print("Selected Features: ", boruta_selector.support_)    # check selected features
 

print("Ranking: ",boruta_selector.ranking_)               # check ranking of features

print("Number of significant features: ", boruta_selector.n_features_)
# Out:
# Selected Features:  [False  True  True  True False  True False False False  True  True  True
#  False  True False False  True  True  True  True  True False False False
#   True False  True False  True  True False]
# Ranking:  [ 2  1  1  1  2  1 11  9  7  1  1  1 10  1 12  7  1  1  1  1  1  8  5  3
#   1  2  1  3  1  1  5]
# Number of significant features:  17

# %%
selected_rf_features = pd.DataFrame({'Feature':list(X_train.columns),
                                      'Ranking':boruta_selector.ranking_})
selected_rf_features.sort_values(by='Ranking')
# Out:
#                     Feature  Ranking
# 10         AvgHouseholdSize        1
# 24   PctPublicCoverageAlone        1
# 13               PctHS18_24        1
# 17        PctBachDeg25_Over        1
# 11           PercentMarried        1
# 20       PctPrivateCoverage        1
# 9           MedianAgeFemale        1
# 29     PctMarriedHouseholds        1
# 26                 PctBlack        1
# 28             PctOtherRace        1
# 5            povertyPercent        1
# 19     PctUnemployed16_Over        1
# 3                 medIncome        1
# 2             incidenceRate        1
# 1          avgDeathsPerYear        1
# 18       PctEmployed16_Over        1
# 16             PctHS25_Over        1
# 0               avgAnnCount        2
# 4                popEst2015        2
# 25                 PctWhite        2
# 27                 PctAsian        3
# 23        PctPublicCoverage        3
# 30                BirthRate        5
# 22       PctEmpPrivCoverage        5
# 8             MedianAgeMale        7
# 15          PctBachDeg18_24        7
# 21  PctPrivateCoverageAlone        8
# 7                 MedianAge        9
# 12             PctNoHS18_24       10
# 6               studyPerCap       11
# 14          PctSomeCol18_24       12

# %%
test_new_data = X_test.copy()
test_new_data.head()
# Out:
#       avgAnnCount  avgDeathsPerYear  ...  PctMarriedHouseholds  BirthRate
# 6       44.000000                14  ...             57.241116   8.012821
# 2639   233.000000                69  ...             49.658346   5.222637
# 2886  1962.667684                32  ...             59.422975   6.386702
# 588     90.000000                39  ...             46.030190   5.540488
# 797    415.000000               164  ...             49.599540   5.981091
#
# [5 rows x 31 columns]

# %%
X_test.head()
# Out:
#       avgAnnCount  avgDeathsPerYear  ...  PctMarriedHouseholds  BirthRate
# 6       44.000000                14  ...             57.241116   8.012821
# 2639   233.000000                69  ...             49.658346   5.222637
# 2886  1962.667684                32  ...             59.422975   6.386702
# 588     90.000000                39  ...             46.030190   5.540488
# 797    415.000000               164  ...             49.599540   5.981091
#
# [5 rows x 31 columns]

# %%
X_important_train = boruta_selector.transform(np.array(X_train))
X_important_test = boruta_selector.transform(np.array(test_new_data))

# %%
# Create a new random forest classifier for the most important features
rf_important = RandomForestRegressor(random_state=1, n_estimators=1000, n_jobs = -1)

# Train the new classifier on the new dataset containing the most important features
rf_important.fit(X_important_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=1000, n_jobs=-1, oob_score=False,
#                       random_state=1, verbose=0, warm_start=False)

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score

#print result of MSE
print(metrics.mean_squared_error(y_test, rf_important.predict(X_important_test)))
# Out:
# 202.36030549803672

# %%
# Edit test data
test_data = test_data.drop(columns=['binnedInc','Geography'])
test_data.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  ...  PctMarriedHouseholds  BirthRate
# 0  2092.000000               763  ...             56.335344   6.825886
# 1    94.000000                41  ...             55.288859   2.292861
# 2   126.000000                43  ...             52.614465  10.502567
# 3  1962.667684                16  ...             55.044700   9.342231
# 4  1962.667684                 4  ...             47.826087  10.029499
#
# [5 rows x 31 columns]

# %%
# Filling the null values using either mean or median
import statistics

cancer_7 = test_data[test_data['PctEmployed16_Over'].isnull() == False]
cancer_8 = test_data[test_data['PctPrivateCoverageAlone'].isnull() == False]
cancer_9 = test_data[test_data['PctSomeCol18_24'].isnull() == False]

mean7 = statistics.mean(cancer_7['PctEmployed16_Over'])
mean8 = statistics.mean(cancer_8['PctPrivateCoverageAlone'])
mean9 = statistics.mean(cancer_9['PctSomeCol18_24'])

test_data['PctEmployed16_Over'] = test_data['PctEmployed16_Over'].fillna(mean7)
test_data['PctPrivateCoverageAlone'] = test_data['PctPrivateCoverageAlone'].fillna(mean8)
test_data['PctSomeCol18_24'] = test_data['PctSomeCol18_24'].fillna(mean9)

# %%
X_important_predict = boruta_selector.transform(np.array(test_data))

# %%
pd.DataFrame(X_important_predict)
# Out:
#         0           1        2     3   ...    13         14         15         16
# 0    763.0  341.000000  34368.0  33.5  ...  28.2   0.620104   5.804689  56.335344
# 1     41.0  445.200000  35615.0  21.5  ...  26.4   0.836770   0.029885  55.288859
# 2     43.0  425.700000  76672.0   7.6  ...   5.9   1.114294   1.844348  52.614465
# 3     16.0  453.549422  45856.0  11.4  ...  15.5   0.381749   0.163607  55.044700
# 4      4.0  453.549422  53739.0  10.9  ...  11.2   0.358423   0.000000  47.826087
# ..     ...         ...      ...   ...  ...   ...        ...        ...        ...
# 757   70.0  501.800000  37625.0  22.1  ...  25.4   0.675000   0.129167  53.063790
# 758   85.0  496.500000  45596.0  13.1  ...  20.7   0.426542   0.035278  57.149659
# 759   93.0  406.200000  37122.0  19.0  ...  23.4   0.625960   0.141727  48.108966
# 760  139.0  511.100000  35555.0  27.4  ...  23.9  32.896529   1.097490  45.683849
# 761    7.0  360.800000  49614.0  13.7  ...  15.3   0.270343  41.930251  64.061410
#
# [762 rows x 17 columns]

# %%
predictions = rf_important.predict(pd.DataFrame(X_important_predict))
predictions = pd.DataFrame(predictions)
predictions.head()
# Out:
#           0
# 0  138.5813
# 1  196.0037
# 2  161.7040
# 3  158.7412
# 4  148.7346

# %%
predictions.rename(columns={0:'prediction'}, inplace=True)
predictions.head()
# Out:
#    prediction
# 0    138.5813
# 1    196.0037
# 2    161.7040
# 3    158.7412
# 4    148.7346

# %%
predictions.to_csv('predictions_A3_Beg.csv',index=False)

# %% [markdown]
# ### GridSearchCV with Boruta Selector Features

# %%
from sklearn.model_selection import GridSearchCV
# Create the parameter grid based on the results of random search 
param_grid = {
    'bootstrap': [True, False],
    'max_depth': [5, 10, 15],
    'n_estimators': [500, 1000, 1500]}

# %%
rf = RandomForestRegressor(random_state = 1)

# Grid search cv
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 2, n_jobs = -1, verbose = 2)

# %%
grid_search.fit(X_important_train, y_train)
# Out:
# Fitting 2 folds for each of 18 candidates, totalling 36 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:  5.7min finished
# GridSearchCV(cv=2, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=1,
#                                              verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'bootstrap': [True, False], 'max_depth': [5, 10, 15],
#                          'n_estimators': [500, 1000, 1500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score

#print result of MSE
print(metrics.mean_squared_error(y_test, grid_search.predict(X_important_test)))
# Out:
# 206.6220131839158

# %%
predictions_grid = grid_search.predict(pd.DataFrame(X_important_predict))
predictions_grid = pd.DataFrame(predictions_grid)
predictions_grid.head()
# Out:
#             0
# 0  138.325383
# 1  196.331789
# 2  162.332587
# 3  157.453852
# 4  150.147707

# %%
predictions_grid.rename(columns={0:'prediction'}, inplace=True)
predictions_grid.head()
# Out:
#    prediction
# 0  138.325383
# 1  196.331789
# 2  162.332587
# 3  157.453852
# 4  150.147707

# %%
predictions_grid.to_csv('predictions_A3_Beg(2).csv',index=False)
